# %%
import pandas as pd
import numpy as np
import altair as alt
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use('Agg')
import plotly.express as px
import numpy as np

# %%
df=pd.read_csv('dash2_ing.csv')
df
# Out:
#        brand_name        goodsNo  \
# 0             닥터지  A000000154177
# 1             닥터지  A000000154177
# 2             닥터지  A000000154177
# 3             닥터지  A000000154177
# 4             닥터지  A000000154177
# ...           ...            ...
# 104260         가히  A000000169124
# 104261         가히  A000000169124
# 104262         가히  A000000169124
# 104263         가히  A000000169124
# 104264         가히  A000000169124
#
#                                                  gdasCont  \
# 0       닥터지는 스킨케어 제품으로 다 잘 맞아서 항상 사용하고 수딩 라인이 특히 순하고 잘...
# 1       거의년째 사용중인 제품입니다.원래는 해당 스킨으로 적셔져 있는 스킨팩을 사용했었는데...
# 2                     보습보다는 진정에 좋은 상품인 거같아요 자극없이 괜찮은 거같아요
# 3       닥터지토너를 항상 사용하는터라 대용량 크기로 구매하게 되는거 같아요할인된 가격으로 ...
# 4       화이트헤드에 좋다고 해서 샀는데크게는 잘 모르겠는데 더 늘어나지는않는거 같아요많이 ...
# ...                                                   ...
# 104260                           좋아요저렴해요재구매각잘샀네요 이것만 사용해요
# 104261                좋으네요 짱짱 다음에도 시킬 것 같아요 어머니 완전 만족 중이심
# ...

# %%
dash_crawling = df[['brand_name','stars_updated','label']]

# %%
dash_crawling
# Out:
#        brand_name  stars_updated  label
# 0             닥터지            6.0      3
# 1             닥터지            6.0      3
# 2             닥터지            5.0      2
# 3             닥터지            6.0      3
# 4             닥터지            5.0      2
# ...           ...            ...    ...
# 104260         가히            1.0      0
# 104261         가히            5.0      2
# 104262         가히            6.0      3
# 104263         가히            6.0      3
# 104264         가히            5.0      2
#
# [104265 rows x 3 columns]

# %%
dash_crawling.to_csv("dash.csv", index = False)
