# %%
import pandas as pd
import numpy as np
import altair as alt
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use('Agg')
import plotly.express as px
import numpy as np

# %%
# %pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df= pd.read_csv('oliveyoung_labeled.csv')

# %%
df
# Out:
#        brand_name        goodsNo  \
# 0             닥터지  A000000182369
# 1             닥터지  A000000182369
# 2             닥터지  A000000182369
# 3             닥터지  A000000182369
# 4             닥터지  A000000182369
# ...           ...            ...
# 110877       에스트라  A000000130138
# 110878       에스트라  A000000130138
# 110879       에스트라  A000000130138
# 110880       에스트라  A000000130138
# 110881       에스트라  A000000130138
#
#                                                  gdasCont  \
# 0       유명하데서 샀는데 저한테는 딱 맞는다는 느낌은 별로 안들었습니다 ㅠㅠ 그래도 무난하...
# 1       2달 정도는 쓰는 것 같고 손등에 바르면 살짝 미끌거리긴한대 얼굴에 바르면 그런느낌은 x
# 2                여드름 피부에 좋아요\r\n갑자기 여드름 많이 났는데 이거 쓰고 좋아진듯
# 3                  대용량이라 양도많고 피부에 부담없이 닦토로 사용할 수 있어서 좋아요.
# 4                            닥토로사용하는데 자극없이 쓰기좋아요.향은 무향이네요
# ...                                                   ...
# 110877               샤워하고나서 바로 얼굴에 뿌려요~심한 건성인데 촉촉하니 좋네요^^
# 110878  이상품은 처음보는데 평소에 다른 아토베리어 라인 다써봐서 그냥 사버렸움 \r\n다 ...
# ...

# %%
dash_crawling = df[['brand_name','goodsNm','goodsNo','stars_updated','label']]

# %%
dash_crawling
# Out:
#        brand_name                            goodsNm        goodsNo  \
# 0             닥터지  닥터지 레드블레미쉬 클리어 수딩 토너 300ml+화장솜 기획  A000000182369
# 1             닥터지   [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# 2             닥터지   [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# 3             닥터지   [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# 4             닥터지   [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# ...           ...                                ...            ...
# 110877       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
# 110878       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
# 110879       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
# 110880       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
# 110881       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
#
#         stars_updated  label
# 0                 4.0      1
# 1                 5.0      1
# 2                 5.0      1
# 3                 5.0      1
# ...

# %%
#dashboard를 위한 csv 파일 저장.
dash_crawling.to_csv("dash.csv", index = False)

# %%
df= pd.read_csv('dash.csv')

# %% [markdown]
# ### 시각화 구현

# %%
df
# Out:
#        brand_name                            goodsNm        goodsNo  \
# 0             닥터지  닥터지 레드블레미쉬 클리어 수딩 토너 300ml+화장솜 기획  A000000182369
# 1             닥터지   [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# 2             닥터지   [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# 3             닥터지   [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# 4             닥터지   [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# ...           ...                                ...            ...
# 110877       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
# 110878       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
# 110879       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
# 110880       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
# 110881       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
#
#         stars_updated  label
# 0                 4.0      1
# 1                 5.0      1
# 2                 5.0      1
# 3                 5.0      1
# ...

# %%
df['stars_updated'].plot()
# Out:
# <AxesSubplot:>

# %%
#히스토그램 x축이 반드시 수량이므로 stars_updated y축 brand명 사용?

# %%
#브랜드별 구분.
df3 = df.loc[df['brand_name'] == '닥터지']
df3
# Out:
#       brand_name                                 goodsNm        goodsNo  \
# 0            닥터지       닥터지 레드블레미쉬 클리어 수딩 토너 300ml+화장솜 기획  A000000182369
# 1            닥터지        [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# 2            닥터지        [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# 3            닥터지        [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# 4            닥터지        [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# ...          ...                                     ...            ...
# 27146        닥터지  닥터지 더모이스처 배리어 D 인텐스 크림 기획 (100ml+30ml)  A000000157774
# 27147        닥터지  닥터지 더모이스처 배리어 D 인텐스 크림 기획 (100ml+30ml)  A000000157774
# 27148        닥터지  닥터지 더모이스처 배리어 D 인텐스 크림 기획 (100ml+30ml)  A000000157774
# 27149        닥터지  닥터지 더모이스처 배리어 D 인텐스 크림 기획 (100ml+30ml)  A000000157774
# 27150        닥터지  닥터지 더모이스처 배리어 D 인텐스 크림 기획 (100ml+30ml)  A000000157774
#
#        stars_updated  label
# 0                4.0      1
# 1                5.0      1
# ...

# %%
grouped_data = df.groupby(['brand_name', 'stars_updated']).size().reset_index(name='count')

    # 막대 그래프 생성
fig10, ax = plt.subplots(figsize=(12, 8))

    # x축에는 brand 칼럼 값을, y축에는 count 칼럼 값을 지정하여 막대 그래프 생성
for stars_updated, color in zip(grouped_data['stars_updated'].unique(), ['red', 'orange', 'yellow', 'green', 'blue', 'purple']):
    filtered_data = grouped_data[grouped_data['stars_updated'] == stars_updated]
    ax.bar(filtered_data['brand_name'], filtered_data['count'], label=stars_updated, color=color)

ax.legend(title='Stars', loc='upper right')

# %%
#브랜드별 구분.
df4 = df1.loc[df1['stars_updated'] == 6.0]
df4
# Out:
#        brand_name                            goodsNm        goodsNo  \
# 5             닥터지  닥터지 레드블레미쉬 클리어 수딩 토너 300ml+화장솜 기획  A000000182369
# 9             닥터지   [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# 10            닥터지   [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# 11            닥터지   [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# 13            닥터지   [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# ...           ...                                ...            ...
# 110874       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
# 110875       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
# 110878       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
# 110879       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
# 110880       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
#
#         stars_updated  label
# 5                 6.0      1
# 9                 6.0      1
# 10                6.0      1
# 11                6.0      1
# ...

# %%
stars_updated_6 = [6]
df1 = df1.loc[df['stars_updated'].isin(stars_updated_6)]
df1
# Out:
#        brand_name                            goodsNm        goodsNo  \
# 5             닥터지  닥터지 레드블레미쉬 클리어 수딩 토너 300ml+화장솜 기획  A000000182369
# 9             닥터지   [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# 10            닥터지   [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# 11            닥터지   [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# 13            닥터지   [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  A000000182369
# ...           ...                                ...            ...
# 110874       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
# 110875       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
# 110878       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
# 110879       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
# 110880       에스트라          에스트라 아토베리어365 크림미스트 120ml  A000000130138
#
#         stars_updated  label
# 5                 6.0      1
# 9                 6.0      1
# 10                6.0      1
# 11                6.0      1
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 8))
x = np.arange(len(df1.brand_name.unique()))

# Define bar width. We'll use this to offset the second bar.
bar_width = 0.4

# Note we add the `width` parameter now which sets the width of each bar.
b1 = ax.bar(x, df1.loc[df1['stars_updated'] == 6.0],
            width=bar_width)
# Same thing, but offset the x by the width of the bar.
b2 = ax.bar(x + bar_width, df1.loc[df1['stars_updated'] == 5.0],
            width=bar_width)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17080/615737152.py in <module>
#       6
#       7 # Note we add the `width` parameter now which sets the width of each bar.
# ----> 8 b1 = ax.bar(x, df1.loc[df1['stars_updated'] == 6.0],
#       9             width=bar_width)
#      10 # Same thing, but offset the x by the width of the bar.
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2277
#    2278         if orientation == 'vertical':
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 8))
x = np.arange(len(df1.brand_name.unique()))

# Define bar width. We'll use this to offset the second bar.
bar_width = 0.4

# Note we add the `width` parameter now which sets the width of each bar.
b1 = ax.bar(x, df1.loc[df1['stars_updated'] == 6.0],
            width=bar_width)
# Same thing, but offset the x by the width of the bar.
b2 = ax.bar(x + bar_width, df1.loc[df1['stars_updated'] == 5.0],
            width=bar_width)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17080/1201326183.py in <module>
#       6
#       7 # Note we add the `width` parameter now which sets the width of each bar.
# ----> 8 b1 = ax.bar(x, df1.loc[df1['stars_updated'] == 6.0],
#       9             width=bar_width)
#      10 # Same thing, but offset the x by the width of the bar.
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2277
#    2278         if orientation == 'vertical':
# ...
