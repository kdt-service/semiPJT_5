# %% [markdown]
# ***리뷰 뽑아오는 코드***

# %%
import time
import pandas as pd
import numpy as np
import requests
import json
import os

final_review_list = list()
for idx in range(23,26):
    base_url = 'https://www.oliveyoung.co.kr/store/goods/getGdasNewListJson.do?'
    headers = {'X-Requested-With' : 'XMLHttpRequest'}
    params = {
        'goodsNo' : 'A000000148253', # 상품 사전 가져오기 ==> 여기 부분 바꾸고
        'gdasSort': '02', # 그대로 놔두기
        'itemNo' : 'all_search',
        'pageIdx' : str(1 + idx), # 페이지 반복문 필요 ==> 여기 부분 바꾸고 
        'cTypeLength' : '0'
    }
    tmp_review_list = list()
    res = requests.get(base_url, headers = headers, params=params)
    crawled_data = json.loads(res.text)
    
    for i in range(len(crawled_data['gdasList'])):
        tmp_review_list.append(crawled_data['gdasList'][i]['gdasCont'])
        print(crawled_data['gdasList'][i]['gdasCont'])
    final_review_list.extend(tmp_review_list)
        
    if tmp_review_list == []:
        final_review_list.append('여기까지')
        break
        
    time.sleep(0.05)
    
# final_review_list
# Out:
# 급하게 찾는 제품이 없어 처음 사용해봤는데 촉촉하니 괜찮아요
# 피부가 민감한 건성이라 자극없는 제품을 선호합니다. 약콩이라 피부에 좋을 것 같아 구매했는데 일단 향은 거의 없다고 보시면 되고 솜에 뭍혀서 얼굴을 닦았을 때 자극없이 잘 흡수됩니다. 한 달 이상 사용중인데 피부 이상없이 사용하고 있습니다.
# 영양 토너 정말 좋은거 같아요.
# 앞으로 쭉 사용할 생각입니다!!
# 피부가 거칠어진 것 같아서 진정과 보습에 도움이 되는 토너를 사려고 올리브영에 방문했어요. 여러 테스터에 마음이 흔들렸고 무엇보다도 직원분께서 다른 제품을 추천해주셔서 고민을 많이 했는데 약콩 토너로 정했습니다. 1. 세일로 인한 합리적인 가격과 2. 순한 성분 3. 귀여운 패키지에 마음을 정한 것이었어요.
#
# 패키지 입구는 이전에도 독도토너 쓰면서도 느꼈지만.. 주변에 묻어요. 맑은 콩물이라 더럽게 남진 않지만 깔끔하게 나오면 좋겠어요.
#
# 샤워 후, 아침 저녁으로 발랐습니다. 한 번 바르면 건성인 제 피부에는 아무 변화가 없지만 두세번 두드리며 바르면 쫀쫀한 느끼이 바로 들어요. 저렴하게 구입했기 때문에 샤워 후 온몸에 발라줬는데 정말 온몸이 촉촉하고 향도 좋아 기분이 좋았습니다. 무엇보다도 뜨거운 여름에 거칠어진 피부가 약콩토너를 사용한지 일주일도 안되어 진정되었다는 점이 좋았어요! 앞으로 쭉 쓸 의향이 있습니다.
# 좋아요! 순하고 좋은 제품인 것 같아요! 수분감이 그렇게 느껴지진 안ㄹ아요!
# 성분이 순한 게 느껴집니다 세일 할 때 사면 좋아요 재구매 의향있습니다
# ✔️솔직 구매후기
# 라운드랩 독도 제품과 자작나무 제품 둘 다 사용해보고 라운드랩 제품이 예민한 제 피부에 잘 맞았어서 새로나온 약콩 제품도 스킨부터 도전해볼라고 구매해보았습니다 !!!!
#
# 이틀간 오전에는 자작나무토너를 저녁에는 약콩토너를 사용해봤어요.
# 순하고, 트러블도 없고 흡수력도 좋았어요. 그리고 냄새도 99%없어서 마음에 들었답니다.
# 그런데 40대라서 그런지 약콩토너는 2~3회 레이어드해서 쫩쫩~ 발라줘야 촉촉함이 느껴지더라고요.
# 개인적으로 세라마이드성분이 있어 촉촉함을 기대했었는데 그부분이 살짝 아쉬웠지만 레이어드해서 사용하면 충분히 촉촉함을 느낄 수 있어 만족해요.
# 촉촉함을 자작나무와 약콩토너를 비교하자면... 자작나무가 좀더 촉촉했어요
# 와 진짜 이거 너무 좋아요!! 이렇게 순하고 촉촉한 스킨 처음 봤어요. 일단 저는 얼굴에 뭐를 발라도 속건조가 잡히지 않았던 피부인데 약콩 토너 쓰고 80퍼센트는 잡혔어요. 정말 대박.. 독도 토너쓰고 얼굴이 뒤집혀서 뭘쓸지 둘러보던중에 화해에서 약콩 스킨 성분이 정말 순하길래 사봤는데 사길 잘했어요. 앞으로 단종되지않는 이상 절대 다른 제품으로 바꿀일은 없을것같아요. 별로 유명하지 않아서 사라질까봐 두렵지만.. 주위에 좋다고 알려주고 다녀야겠어요.. 저처럼 건조하고 속건조 심하신 분들 제발 이거 한번 써보세요..!! 약콩 토너를 손으로 두둘두둘해주고 바이오더마 인텐시브 크림으로 마무리해주면 파워 촉촉.. 냄새는 무향에 95퍼센트 가깝고 나머지 5퍼는 약간의 콩냄새가 나는것같아요. 다시 생각해봐도 이렇게 좋은제품이 왜 유명하지 않은지 의문이네요. 제 리뷰를 보시는 민감성+건성 이신분들은 세일기간에 이거 한번 꼭 써보세요! 대체적으로 라운드랩 제품이 순하고 가격도 합리적으로 나오는것같아서 좋네용.

# %%
### 브랜드별로 따로

# %%
import time
import pandas as pd
import numpy as np
import requests
import json
import os

file_path='./goodsNo_dict.json'
with open(file_path, 'r', encoding='utf-8-sig') as file:
    goodsNo_json = json.load(file)

# %%
# Out:
# 20

# %%
import time
import pandas as pd
import numpy as np
import requests
import json
import os

# json파일 불러오기 ==> json파일 다운로드 및 경로는 바꿔야될 수 있습니다. 
file_path='./goodsNo_dict.json'
with open(file_path, 'r', encoding='utf-8-sig') as file:
    goodsNo_json = json.load(file)

# review와 관련된 정보들을 가져올 dictionary
review_dict = {
    'brand_name' : [], # 브랜드 이름
    'goodsNo' : [], # 상품 고유 번호
    'gdasCont' : [], # 상품 리뷰
    'goodsNm' : [], # 상품 이름
    'dispRegDate' : [], # 리뷰날짜
    'gdasSeq' : [], # 리뷰 구분하기 위한 리뷰 순서?
    'subcategory' : [], # 상품 카테고리 번호 
#     'review_star' : []  # 리뷰 별점 
}


# brand_list = ['닥터지', '라운드랩', '라네즈']
brand_list = ['닥터지', '라운드랩'] # 우선 닥터지 하나만 
for brand in brand_list:
    for sub_cat, goodsNo in goodsNo_json[brand].items(): 
        for goods_num in goodsNo[:1]: 
            headers = {'X-Requested-With' : 'XMLHttpRequest'}
            tmp_url = 'https://www.oliveyoung.co.kr/store/goods/getGdasNewListJson.do?'+\
            'goodsNo={}&gdasSort=02&itemNo=all_search&pageIdx=1&cTypeLength=0'.format(goods_num) 

            res = requests.get(tmp_url, headers=headers)
            crawled_data = json.loads(res.text)
            for review_idx in range(len(crawled_data['gdasList'])):

                # review_dict에 결과물 넣기 
                review_dict['goodsNo'].append(goods_num) # goodsNo
                review_dict['goodsNm'].append(crawled_data['gdasList'][review_idx]['goodsNm']) # 상품이름
                review_dict['gdasCont'].append(crawled_data['gdasList'][review_idx]['gdasCont']) # 상품리뷰
                review_dict['dispRegDate'].append(crawled_data['gdasList'][review_idx]['dispRegDate']) # 상품리뷰 날짜
                review_dict['gdasSeq'].append(crawled_data['gdasList'][review_idx]['gdasSeq']) # 상품 구별을 위한 seq number
                review_dict['subcategory'].append(sub_cat) # subcategory 넘버
                review_dict['brand_name'].append(brand) # 브랜드 이름 
                
                time.sleep(0.03)
                
df = pd.DataFrame(review_dict)
df
# Out:
#    brand_name        goodsNo  \
# 0         닥터지  A000000182369
# 1         닥터지  A000000182369
# 2         닥터지  A000000182369
# 3         닥터지  A000000182369
# 4         닥터지  A000000182369
# 5         닥터지  A000000182369
# 6         닥터지  A000000182369
# 7         닥터지  A000000182369
# 8         닥터지  A000000182369
# 9         닥터지  A000000182369
# 10        닥터지  A000000164615
# 11        닥터지  A000000164615
# 12        닥터지  A000000164615
# 13        닥터지  A000000164615
# 14        닥터지  A000000164615
# 15        닥터지  A000000164615
# 16        닥터지  A000000164615
# 17        닥터지  A000000164615
# 18        닥터지  A000000164615
# 19        닥터지  A000000164615
# 20       라운드랩  A000000175945
# 21       라운드랩  A000000175945
# 22       라운드랩  A000000175945
# 23       라운드랩  A000000175945
# 24       라운드랩  A000000175945
# 25       라운드랩  A000000175945
# 26       라운드랩  A000000175945
# 27       라운드랩  A000000175945
# 28       라운드랩  A000000175945
# 29       라운드랩  A000000175945
# 30       라운드랩  A000000166586
# 31       라운드랩  A000000166586
# 32       라운드랩  A000000166586
# 33       라운드랩  A000000166586
# 34       라운드랩  A000000166586
# 35       라운드랩  A000000166586
# 36       라운드랩  A000000166586
# 37       라운드랩  A000000166586
# 38       라운드랩  A000000166586
# 39       라운드랩  A000000166586
# 40       라운드랩  A000000150447
# 41       라운드랩  A000000150447
# 42       라운드랩  A000000150447
# 43       라운드랩  A000000150447
# 44       라운드랩  A000000150447
# 45       라운드랩  A000000150447
# 46       라운드랩  A000000150447
# 47       라운드랩  A000000150447
# 48       라운드랩  A000000150447
# 49       라운드랩  A000000150447
#
#                                              gdasCont  \
# 0            여드름 피부에 좋아요\r\n갑자기 여드름 많이 났는데 이거 쓰고 좋아진듯
# 1              대용량이라 양도많고 피부에 부담없이 닦토로 사용할 수 있어서 좋아요.
# 2                        닥토로사용하는데 자극없이 쓰기좋아요.향은 무향이네요
# 3   제가 피부가 진짜 예민한 편이라 아무거나 못 쓰는데 닥터지 토너는 진짜 믿고 쓸 수...
# 31                   촉촉하고 보습에 좋아요 유명해서 구매해보았는데 좋네요 ㅎㅎ
# 32              수분크림 튜브형태로 나와서 더 좋은 것 같아요. 사용이 편리하네요~
# 33  저한테는 너무 안맞아서 아쉬웠던,,ㅠㅠ 그치만 무난하게 사용하기 좋을 것 같아요! ...
# 34          자작나무 라인 모두가 끈적이지 않고 쓸 수 있어서 복합성에겐 너무 좋았어요
# 35                 자극없이순하고 눈에들어가도 따갑지않을정도로 순해요 보습도좋아요
# 36                 라운드랩 자작나무 수분크림 피부에 잘 맞고 촉촉해서 좋습니다.
# 37  전 발랐을때 얼굴에 끈적이는걸 안좋아 하는데 이 제품은 끈적이지도 않고 금방 스며들...
# 38  촉촉하고 좋긴한데 \r\n알갱이가 있는줄몰랐어여 ㅠ 너무 번거롭고 \r\n화장할때도...
# 39  수분 크림이 일정 시간이 지나면 건조해지는 감이 있어서 다 거기서 거기라고 생각하는...
# 40           항상 사용하는 제품이지만 역시 독도\r\n수분이 너무 잘 유지되어 좋아요
# 41  피부가 건조할때, 자기전에 뿌려주면 좋은 제품이에요 벌써 세병째 사용중입니다 평소 ...
# 42                분사가 너무 좋아요 한번 뿌리면 얼굴에 다 뿌려져서 너무 좋아요
# 43  남자라서 그런거 안써도 된다라고\r\n생각을 하면서 긴가민가하면서\r\n사용하게됬는...
# 44              자극적이지 않고 끈적임 없는 적당한 보습 효과로 만족하고 있습니다.
# 45                   좋아요. 세수하고 난 직후 바로 뿌리기 좋은 미스트입니다.
# 46           그냥 물을 고운 입자 형태로 뿌리는 느낌임. 분사력은 좋음. 재구매 없음
# 47  2통 이상 쓴 제품이에요 세안직후에 쓰면 촉촉한게 좋아요 자기 전에 뿌리고 자면 다...
# 48           피부가 자꾸 땡기는서 같아 구매했는데, 사용후부터는 당기는 느낌이 적어요
# 49  미스트가 필요해서 아무거나 샀는데 이거 완전 대박템이였어요!!\r\n\r\n가격도 ...
#
#                                            goodsNm dispRegDate   gdasSeq  \
# 0                 [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  2023.04.26  19122812
# 1                 [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  2023.04.26  19121470
# 2                 [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  2023.04.26  19114373
# 3                닥터지 레드블레미쉬 클리어 수딩 토너 300ml+화장솜 기획  2023.04.24  19089567
# 4                 [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  2023.04.24  19089130
# 5                 [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  2023.04.24  19084807
# 6                 [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  2023.04.24  19084805
# 7                 [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  2023.04.24  19082298
# 8                 [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  2023.04.24  19081777
# 9                 [증량] 닥터지 레드 블레미쉬 클리어 수딩 토너 500ml  2023.04.24  19073750
# 37              라운드랩 자작나무 수분크림 (본품80ml+20ml 추가 증정)  2023.04.26  19113109
# 38     [단독대용량] 라운드랩 자작나무 수분 크림 120ml 기획 (+수분패드 4매)  2023.04.26  19112888
# 39     [단독대용량] 라운드랩 자작나무 수분 크림 120ml 기획 (+수분패드 4매)  2023.04.25  19108630
# 40                          라운드랩 1025 독도 미스트 150ml  2023.04.26  19118970
# 41                          라운드랩 1025 독도 미스트 150ml  2023.04.24  19087646
# 42                          라운드랩 1025 독도 미스트 150ml  2023.04.22  19041274
# 43                          라운드랩 1025 독도 미스트 150ml  2023.04.21  19036764
# 44                          라운드랩 1025 독도 미스트 150ml  2023.04.17  18961432
# 45                          라운드랩 1025 독도 미스트 150ml  2023.04.17  18959332
# 46                          라운드랩 1025 독도 미스트 150ml  2023.04.14  18908899
# 47                          라운드랩 1025 독도 미스트 150ml  2023.04.14  18896676
# 48                          라운드랩 1025 독도 미스트 150ml  2023.04.13  18887239
# 49                          라운드랩 1025 독도 미스트 150ml  2023.04.12  18848000
#
#         subcategory
# 0   100000100010008
# 1   100000100010008
# 2   100000100010008
# 3   100000100010008
# 4   100000100010008
# 5   100000100010008
# 6   100000100010008
# 7   100000100010008
# 8   100000100010008
# 9   100000100010008
# 10  100000100010009
# 11  100000100010009
# 12  100000100010009
# 13  100000100010009
# 14  100000100010009
# 15  100000100010009
# 16  100000100010009
# 17  100000100010009
# 18  100000100010009
# 19  100000100010009
# 20  100000100010008
# 21  100000100010008
# 22  100000100010008
# 23  100000100010008
# 24  100000100010008
# 25  100000100010008
# 26  100000100010008
# 27  100000100010008
# 28  100000100010008
# 29  100000100010008
# 30  100000100010009
# 31  100000100010009
# 32  100000100010009
# 33  100000100010009
# 34  100000100010009
# 35  100000100010009
# 36  100000100010009
# 37  100000100010009
# 38  100000100010009
# 39  100000100010009
# 40  100000100010010
# 41  100000100010010
# 42  100000100010010
# 43  100000100010010
# 44  100000100010010
# 45  100000100010010
# 46  100000100010010
# 47  100000100010010
# 48  100000100010010
# 49  100000100010010

# %%
import time
import pandas as pd
import numpy as np
import requests
import json
import os

# json파일 불러오기 ==> json파일 다운로드 및 경로는 바꿔야될 수 있습니다. 
file_path='./goodsNo_dict.json'
with open(file_path, 'r', encoding='utf-8-sig') as file:
    goodsNo_json = json.load(file)

# review와 관련된 정보들을 가져올 dictionary
review_dict = {
    'brand_name' : [], # 브랜드 이름
    'goodsNo' : [], # 상품 고유 번호
    'gdasCont' : [], # 상품 리뷰
    'goodsNm' : [], # 상품 이름
    'dispRegDate' : [], # 리뷰날짜
    'gdasSeq' : [], # 리뷰 구분하기 위한 리뷰 순서?
    'subcategory' : [], # 상품 카테고리 번호 
#     'review_star' : []  # 리뷰 별점 
}


# brand_list = ['닥터지', '라운드랩', '라네즈']
brand_list = ['닥터지'] # 우선 닥터지 하나만 
for brand in brand_list:
    for sub_cat, goodsNo in goodsNo_json[brand].items(): 
        for goods_num in goodsNo[:1]: 
            page_num = 1
            while True:
                headers = {'X-Requested-With' : 'XMLHttpRequest'}
                tmp_url = 'https://www.oliveyoung.co.kr/store/goods/getGdasNewListJson.do?'+\
                'goodsNo={}&gdasSort=02&itemNo=all_search&'.format(goods_num) +\
                'pageIdx={}&cTypeLength=0'.format(str(page_num)) 

                res = requests.get(tmp_url, headers=headers)
                crawled_data = json.loads(res.text)
                check_list = list()
                for review_idx in range(len(crawled_data['gdasList'])):
                    check_list.append(crawled_data['gdasList'][review_idx]['gdasCont')
                    # review_dict에 결과물 넣기 
                    review_dict['goodsNo'].append(goods_num) # goodsNo
                    review_dict['goodsNm'].append(crawled_data['gdasList'][review_idx]['goodsNm']) # 상품이름
                    review_dict['gdasCont'].append(crawled_data['gdasList'][review_idx]['gdasCont']) # 상품리뷰
                    review_dict['dispRegDate'].append(crawled_data['gdasList'][review_idx]['dispRegDate']) # 상품리뷰 날짜
                    review_dict['gdasSeq'].append(crawled_data['gdasList'][review_idx]['gdasSeq']) # 상품 구별을 위한 seq number
                    review_dict['subcategory'].append(sub_cat) # subcategory 넘버
                    review_dict['brand_name'].append(brand) # 브랜드 이름 
                
                if check_list == []:
                    break
                        
                page_num+=1
                
                
                time.sleep(0.03)
                
df = pd.DataFrame(review_dict)
df

# %%
import time
import pandas as pd
import numpy as np
import requests
import json
import os

final_review_list = list()
page_num = 25
while True:
    base_url = 'https://www.oliveyoung.co.kr/store/goods/getGdasNewListJson.do?'
    headers = {'X-Requested-With' : 'XMLHttpRequest'}
    params = {
        'goodsNo' : 'A000000148253', # 상품 사전 가져오기 ==> 여기 부분 바꾸고
        'gdasSort': '02', # 그대로 놔두기
        'itemNo' : 'all_search',
        'pageIdx' : str(page_num), # 페이지 반복문 필요 ==> 여기 부분 바꾸고 
        'cTypeLength' : '0'
    }
    
    res = requests.get(base_url, headers = headers, params=params)
    crawled_data = json.loads(res.text)
    
    tmp_review_list = list()
    for i in range(len(crawled_data['gdasList'])):
        tmp_review_list.append(crawled_data['gdasList'][i]['gdasCont'])
    final_review_list.extend(tmp_review_list)
#         print(crawled_data['gdasList'][i]['gdasCont'])
#         if crawled_data['gdasList'][i]['gdasCont'] == '':
#             break
           
        
    if tmp_review_list == []:
        final_review_list.append('여기까지')
        break
    page_num+=1

        
time.sleep(0.05)
    
final_review_list
# Out:
# ['문안하게 가볍게 솜으로사용할수있어여 \r\n끈적이지않고 사용하기좋아요',
#  '냄새없어서 좋고 무난하면서 촉촉해서 괜찮은 제품',
#  '화장지우고 나면 마스카라, 아이라인 같은 것 때문에 눈이 좀 아플때가 있잖아요? 너무 건조해서? 그럴때 진정하는 용으로 사용해볼까.. 싶어서 사봤는데 ㅋㅋㅋ아직까지 피부에 크게 트러블 난것도 없구 아토피 있는데 붉어진다던가 간지럽다던가 그런 것도 없어서 좋아요!\r\n화장하기전에 사용하기도 좋아요 ㅋㅋ 근데 저는 지울때 좀 붉어진 피부를 안정 시키기 위한(?) 그런용도로 쓰는게 조금더 안정감있게 사용하기 좋은 것 같아같ㅎㅎ 향은 흠... 무슨 냄새인지 정의는 못하겠는데 거부감은 없어요 그리고 보기에 꾸덕한가? 했는데 그냥 알코올 같은 토너가 아니라 정말 촉촉~한 토너에요',
